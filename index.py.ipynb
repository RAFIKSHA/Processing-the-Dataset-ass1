# %% [markdown]
# # "Let's start by importing the required Python packages."

# %%
# importing packages import pandas as pd

import pandas as pd

# !git clone https://github.com/RAFIKSHA/Processing-the-Dataset-ass1.git
# Out:
# Cloning into 'Processing-the-Dataset-ass1'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 31 (delta 14), reused 21 (delta 9), pack-reused 0
# Receiving objects: 100% (31/31), 130.00 KiB | 5.42 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %% [markdown]
# # Data gathering for operations

# %%
# Read data from CSV file
dataset = pd.read_csv("/content/Processing-the-Dataset-ass1/india.csv")

# %% [markdown]
# # Data visualization

# %%
#Provide a glimpse of the starting records in the DataFrame.
print("Data from CSV file:")
dataset.head()
# Out:
# Data from CSV file:
#                                     State & District  Population    Male
# 0  district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190  \
# 1  district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2  district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3  district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4  district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
#
#    Female  Literate  Male_Literate  Female_Literate    SC  Male_SC  Female_SC
# 0  396164    439654         282823           156831  1048     1046          2  \
# 1  355704    335649         207741           127908   368      343         25
# 2   54516     93770          62834            30936   488      444         44
# 3   63017     86236          56301            29935    18       12          6
# 4  224936    261724         163333            98391   556      406        150
#
# ...

# %%
# Displaying basic information about the DataFrame
print("Basic Information:")
dataset.info()     #Output the summary information of the DataFrame using the df.info() function.
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 51 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State & District                  640 non-null    object
#  1   Population                        640 non-null    int64
#  2   Male                              640 non-null    int64
#  3   Female                            640 non-null    int64
#  4   Literate                          640 non-null    int64
#  5   Male_Literate                     640 non-null    int64
#  6   Female_Literate                   640 non-null    int64
#  7   SC                                640 non-null    int64
#  8   Male_SC                           640 non-null    int64
#  9   Female_SC                         640 non-null    int64
#  10  ST                                640 non-null    int64
# ...

# %%
# Displaying summary statistics of numeric columns
print("Summary Statistics is :")
dataset.describe()   #Generate a statistical summary of the DataFrame using the `df.describe()` function.
# Out:
# Summary Statistics is :
#          Population          Male        Female      Literate  Male_Literate
# count  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02   6.400000e+02  \
# mean   1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06   6.793182e+05
# std    1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06   5.924144e+05
# min    8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03   2.614000e+03
# 25%    8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05   2.764365e+05
# 50%    1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05   5.483525e+05
# 75%    2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06   9.188582e+05
# max    1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06   4.591396e+06
#
#        Female_Literate            SC       Male_SC     Female_SC
# count     6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02  \
# mean      5.138675e+05  3.146537e+05  1.617739e+05  1.528798e+05
# ...

# %% [markdown]
# # Data checking

# %%
# Checking for missing values
print("Missing Values:")
dataset.isnull().sum()
# Out:
# Missing Values:
# State & District                    0
# Population                          0
# Male                                0
# Female                              0
# Literate                            0
# Male_Literate                       0
# Female_Literate                     0
# SC                                  0
# Male_SC                             0
# Female_SC                           0
# ST                                  0
# Male_ST                             0
# Female_ST                           0
# Workers                             0
# Male_Workers                        0
# Female_Workers                      0
# Main_Workers                        0
# Marginal_Workers                    0
# Non_Workers                         0
# Cultivator_Workers                  0
# Agricultural_Workers                0
# Household_Workers                   0
# Other_Workers                       0
# Hindus                              0
# ...

# %% [markdown]
# # Data processing

# %%
# Preprocess data
def preprocess_data(df):
    # Split combined data in the 'state & district' column
    dataset[['district_code','state_name', 'district_name']] = dataset['State & District'].str.split(n=2, expand=True)
    dataset.drop(columns=['State & District'], inplace=True)

    return df

# Preprocess the data
preprocessed_set= preprocess_data(dataset.copy())

# Displaying preprocessed data
print("Preprocessed Data is:")
preprocessed_set.head()
# Out:
# Preprocessed Data is:
#                                     State & District  Population    Male
# 0  district_code:1, state_name:JAMMU AND KASHMIR,...      870354  474190  \
# 1  district_code:2, state_name:JAMMU AND KASHMIR,...      753745  398041
# 2  district_code:3, state_name:JAMMU AND KASHMIR,...      133487   78971
# 3  district_code:4, state_name:JAMMU AND KASHMIR,...      140802   77785
# 4  district_code:5, state_name:JAMMU AND KASHMIR,...      476835  251899
#
#    Female  Literate  Male_Literate  Female_Literate    SC  Male_SC  Female_SC
# 0  396164    439654         282823           156831  1048     1046          2  \
# 1  355704    335649         207741           127908   368      343         25
# 2   54516     93770          62834            30936   488      444         44
# 3   63017     86236          56301            29935    18       12          6
# 4  224936    261724         163333            98391   556      406        150
#
# ...

# %% [markdown]
# # "Managing or Addressing Missing Values"

# %%
# Handle missing values

dataset['Age_Group_50'].fillna(df['Age_Group_50'].median(), inplace=True)

# Display the DataFrame
dataset
# Out:
#      Population    Male  Female  Literate  Male_Literate  Female_Literate
# 0        870354  474190  396164    439654         282823           156831  \
# 1        753745  398041  355704    335649         207741           127908
# 2        133487   78971   54516     93770          62834            30936
# 3        140802   77785   63017     86236          56301            29935
# 4        476835  251899  224936    261724         163333            98391
# ..          ...     ...     ...       ...            ...              ...
# 635       41816   19143   22673     36470          16610            19860
# 636      200222   97809  102413    154916          79903            75013
# 637       36842   20727   16115     25332          15397             9935
# 638      105597   54861   50736     78683          43186            35497
# 639      238142  127283  110859    190266         105794            84472
#
#         SC  Male_SC  Female_SC      ST  ...  Other_Education
# ...

# %% [markdown]
# # Datatype conversion

# %%
# Convert data types
dataset['Age_Group_50'] = dataset['Age_Group_50'].astype(int)
dataset
# Out:
#      Population    Male  Female  Literate  Male_Literate  Female_Literate
# 0        870354  474190  396164    439654         282823           156831  \
# 1        753745  398041  355704    335649         207741           127908
# 2        133487   78971   54516     93770          62834            30936
# 3        140802   77785   63017     86236          56301            29935
# 4        476835  251899  224936    261724         163333            98391
# ..          ...     ...     ...       ...            ...              ...
# 635       41816   19143   22673     36470          16610            19860
# 636      200222   97809  102413    154916          79903            75013
# 637       36842   20727   16115     25332          15397             9935
# 638      105597   54861   50736     78683          43186            35497
# 639      238142  127283  110859    190266         105794            84472
#
#         SC  Male_SC  Female_SC      ST  ...  Other_Education
# ...
